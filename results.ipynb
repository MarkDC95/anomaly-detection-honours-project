# %% [markdown]
# <a href="https://colab.research.google.com/github/MarkDC95/anomaly-detection-honours-project/blob/main/results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import libraries
#import Helper as hp
import IPython.display as ipd
import tensorflow as tf
# import tensorflow_io as tfio
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Import librosa after pandas and numpy
import librosa
import librosa.display

import os
import sys
import warnings
warnings.filterwarnings('ignore')

from IPython.display import display
from IPython.display import Audio
import random

from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix #plot_confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, Flatten, Dense,Reshape, Conv2DTranspose
from tensorflow.keras import Model
from keras.backend import int_shape
from tensorflow.keras.callbacks import EarlyStopping

# %%
def get_model(inputDim, latentDim):
    """
    define the keras model
    the model based on the simple convolutional auto encoder
    """
    input_img = Input(shape=(inputDim[0], inputDim[1], 1))

    # encoder
    x = Conv2D(256, (5, 5),strides=(1,2), padding='same')(input_img)   #32x128 -> 32x64
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(128, (5, 5),strides=(1,2), padding='same')(x)           #32x32
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(64, (5, 5),strides=(2,2), padding='same')(x)          #16x16
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    volumeSize = int_shape(x)
    # at this point the representation size is latentDim i.e. latentDim-dimensional
    x = Conv2D(latentDim, (4,4), strides=(1,1), padding='same')(x)
    encoded = Flatten()(x)


    # decoder
    x = Dense(volumeSize[1] * volumeSize[2] * volumeSize[3])(encoded)
    x = Reshape((volumeSize[1], volumeSize[2], 64))(x)                #4x4

    x = Conv2DTranspose(128, (5, 5),strides=(2,2), padding='same')(x)   #32x32
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(256, (5, 5),strides=(1,2), padding='same')(x)   #32x64
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    decoded = Conv2DTranspose(1, (5, 5),strides=(1,2), padding='same')(x)

    return Model(inputs=input_img, outputs=decoded)

# %%
#AutoEncoder model base purohitt
def autoencoder(input_shape):
    # Encoder
    inputs = tf.keras.Input(shape=input_shape)
    x = tf.keras.layers.Flatten()(inputs)

    x = tf.keras.layers.Dense(512)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)

    x = tf.keras.layers.Dense(512)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)

    x = tf.keras.layers.Dense(512)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)

    encoded = tf.keras.layers.Dense(8)(x)

    # Decoder
    x = tf.keras.layers.Dense(512)(encoded)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)

    x = tf.keras.layers.Dense(512)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)

    x = tf.keras.layers.Dense(512)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)

    x = tf.keras.layers.Dense(np.prod(input_shape))(x)
    decoded = tf.keras.layers.Reshape(input_shape)(x)
    # Autoencoder
    autoencoder_model = tf.keras.models.Model(inputs, decoded)
    return autoencoder_model

# %%
# Get the CAE model
cae_model = get_model(inputDim = (128, 32), latentDim=32)  # You can customize the latent dimension
early_stopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001)

# Compile the model
learning_rate = 0.01
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

# Compile the model
cae_model.compile(optimizer=optimizer, loss='mean_squared_error')  # Using MSE as the loss function

# %%
ids = ['fan_id_00','fan_id_02','fan_id_04','fan_id_06']#['pump_id_00','pump_id_02','pump_id_04','pump_id_06']
random_states = [42, 52, 62]
snr = ['-6 dB', '0 dB', '6 dB']
# Create an empty DataFrame to store the results
for idx in ids:
    results_df = pd.DataFrame(columns=[
        "Machine Type",
        "Machine Number",
        "SNR",
        "Random State Run Number",
        "ROC-AUC",
        "Accuracy",
        "Precision",
        "Recall",
        "F1-Score"
    ])
    machine_type = 'Fan'#'Pump'
    id = idx

    for noise in snr:
        for j in random_states:
            random_state = j
            tf.random.set_seed= random_state
            np.random.seed = random_state

            file_path = fr"/content/drive/MyDrive/cnn preprocess/{id}/{noise}/{str(j)}/"
            X_train =np.load(fr"{file_path}X_train.npy")
            X_test =np.load(fr"{file_path}X_test.npy")
            ground_truth_file = np.load(fr"{file_path}ground_truth.npy")

            # Create the autoencoder model
            input_shape = (128, 32)

            # Reshape the data to (650*9, 128, 32, 1) for training
            X_train_reshaped = X_train.reshape(-1, np.prod(input_shape))
            X_test_reshaped = X_test.reshape(-1, np.prod(input_shape))



            autoencoder_model = autoencoder((np.prod(input_shape),))

            # Compile the model
            learning_rate = 0.01
            optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
            autoencoder_model.compile(optimizer=optimizer, loss='mse')

            # Train the model on the segmented data
            history=autoencoder_model.fit(X_train.reshape(-1, np.prod(input_shape)), X_train.reshape(-1, np.prod(input_shape)),
                                            epochs=15,
                                            batch_size=32,
                                            shuffle=True,
                                            validation_split=0.1)

            # Make predictions on the test data
            reconstructed_data = autoencoder_model.predict(X_test_reshaped)
            # Calculate the reconstruction error for each sample
            mse = np.mean(np.square(X_test_reshaped - reconstructed_data), axis=1)
            ground_truth = list(ground_truth_file)

            # MSE of entire concatenated sample
            outcome_arr = []
            for i in range(len(mse)):
                if i % 9 == 0:
                    outcome_arr.append(np.average(mse[i:i+9]))
            print(f" the {len(outcome_arr)} samples have been concatenated")

            # ROC AUC SCORE
            fpr, tpr, thresholds = roc_curve(ground_truth, outcome_arr)
            roc_auc = auc(fpr, tpr)

            # get the best threshold using Youdens Index
            J = tpr - fpr
            ix = np.argmax(J)
            best_thresh = thresholds[ix]
            print('Best Threshold= %f' % (best_thresh))

            outcome = [0 if i < best_thresh else 1 for i in outcome_arr]

            y_pred = outcome

            accuracy = accuracy_score(ground_truth, y_pred)
            precision = precision_score(ground_truth, y_pred)
            recall = recall_score(ground_truth, y_pred)
            f1 = f1_score(ground_truth, y_pred)

            # Open the text file in append mode
                    # Append the results to the DataFrame
            results_df = results_df.append({
                "Machine Type": machine_type,
                "Machine Number": id,
                "SNR": noise,
                "Random State Run Number": random_state,
                "ROC-AUC": roc_auc,
                "Accuracy": accuracy,
                "Precision": precision,
                "Recall": recall,
                "F1-Score": f1
            }, ignore_index=True)

            #Loss Curve
            plt.figure()
            plt.plot(history.history['loss'], lw=2, color='darkblue')
            plt.plot(history.history['val_loss'], lw=2, color='darkorange')
            plt.title('Autoencoder Loss for DAE model')
            plt.xlabel('Epoch')
            plt.ylabel('Loss')
            plt.legend(['Train', 'Validation'], loc='upper right')
            file_path = f"/content/drive/MyDrive/DAE Results/Loss Curves/{id} {noise} {random_state} Loss Curve.png"
            plt.savefig(file_path)
            plt.close()


            #mse curve
            halfway_point = len(y_pred)/2  # enter halfway point
            plt.figure(figsize=(15, 5))
            # Plot the entire data
            # Create discrete x-values for the bar plot
            x_values = np.arange(len(y_pred))
            # Plot the entire data as discrete bars
            plt.scatter(x_values, outcome_arr, marker='o', label='MSE', s=5, color='black')
            # plt.plot(outcome_arr, )
            # Highlight the right half with a different background color
            plt.axhline(y=best_thresh, color='r', linestyle='-', label=f'threshold = {best_thresh:.4f}')
            plt.axvspan(halfway_point, len(outcome_arr), facecolor='green', alpha=0.2, label='Abnormal Test Data')
            plt.xlabel("Audio sample")
            plt.ylabel("MSE")
            plt.title("MSE of Test Data")
            plt.axvspan(0, halfway_point, facecolor='white', alpha=0.1, label='Normal Test Data')
            plt.legend()  # Add a legend to label the plot elements
            file_path = f"/content/drive/MyDrive/DAE Results/MSE Graphs/{id} {noise} {random_state} MSE Graph.png"
            plt.savefig(file_path)
            plt.close()

            #ROC Plot
            plt.figure()
            lw = 2
            plt.plot(fpr, tpr, color='darkorange',
                    lw=lw, label='ROC curve (area = %0.3f)' % roc_auc)
            plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
            plt.xlim([0.0, 1.0])
            plt.ylim([0.0, 1.05])
            plt.xlabel('False Positive Rate')
            plt.ylabel('True Positive Rate')
            plt.title('Receiver operating characteristic')
            plt.legend(loc="lower right")
            file_path = f"/content/drive/MyDrive/DAE Results/ROC Curves/{id} {noise} {random_state} ROC Curve.png"
            plt.savefig(file_path)
            plt.close()

            # confusion matrix
            conf_mat = confusion_matrix(ground_truth, outcome)
            plt.figure()
            sns.heatmap(conf_mat, cmap="Greens", annot=True, cbar_kws={"label": "Count"}, fmt='d',
                        xticklabels=[0, 1], yticklabels=[0, 1])
            plt.xlabel("Predicted Values")
            plt.ylabel("Actual Values")
            plt.title("Confusion Matrix")
            file_path = f"/content/drive/MyDrive/DAE Results/Confusion Matrices/{id} {noise} {random_state} confusion_matrix.png"
            plt.savefig(file_path)
            plt.close()

            model_path = f"/content/drive/MyDrive/DAE Results/Models/{id} {noise} {random_state} model"
            autoencoder_model.save(model_path)

            print(f"{id} {noise} {random_state} completed")



    csv_file_path = f'/content/drive/MyDrive/DAE Results/Result Metrics/results_{id}_cnn.csv'
    #Save the DataFrame to a CSV file
    results_df.to_csv(csv_file_path, index=False)
# Out:
# Epoch 1/15
# 165/165 [==============================] - 7s 13ms/step - loss: 25.2449 - val_loss: 73.1178
# Epoch 2/15
# 165/165 [==============================] - 2s 15ms/step - loss: 5.7526 - val_loss: 6.6955
# Epoch 3/15
# 165/165 [==============================] - 2s 12ms/step - loss: 5.0268 - val_loss: 5.0926
# Epoch 4/15
# 165/165 [==============================] - 2s 10ms/step - loss: 4.5474 - val_loss: 5.1048
# Epoch 5/15
# 165/165 [==============================] - 2s 10ms/step - loss: 4.4639 - val_loss: 4.6597
# Epoch 6/15
# 165/165 [==============================] - 2s 10ms/step - loss: 4.3706 - val_loss: 4.8256
# Epoch 7/15
# 165/165 [==============================] - 2s 9ms/step - loss: 4.2931 - val_loss: 4.8375
# Epoch 8/15
# 165/165 [==============================] - 2s 10ms/step - loss: 4.1684 - val_loss: 4.7483
# Epoch 9/15
# 165/165 [==============================] - 2s 11ms/step - loss: 4.2064 - val_loss: 5.2030
# Epoch 10/15
# 165/165 [==============================] - 2s 14ms/step - loss: 4.1209 - val_loss: 4.9661
# Epoch 11/15
# 165/165 [==============================] - 2s 11ms/step - loss: 4.0096 - val_loss: 5.2896
# Epoch 12/15
# 165/165 [==============================] - 2s 10ms/step - loss: 4.0626 - val_loss: 5.5598
# Epoch 13/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.8847 - val_loss: 4.7081
# Epoch 14/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.8656 - val_loss: 4.7266
# Epoch 15/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.8557 - val_loss: 4.6454
# 183/183 [==============================] - 1s 2ms/step
#  the 650 samples have been concatenated
# Best Threshold= 4.297944
# fan_id_00 -6 dB 42 completed
# Epoch 1/15
# 165/165 [==============================] - 10s 13ms/step - loss: 26.1435 - val_loss: 1064.4003
# Epoch 2/15
# 165/165 [==============================] - 2s 10ms/step - loss: 5.0714 - val_loss: 7.0010
# Epoch 3/15
# 165/165 [==============================] - 2s 10ms/step - loss: 4.6581 - val_loss: 4.5673
# Epoch 4/15
# 165/165 [==============================] - 2s 10ms/step - loss: 4.3006 - val_loss: 6.3323
# Epoch 5/15
# 165/165 [==============================] - 2s 9ms/step - loss: 3.9954 - val_loss: 5.1480
# Epoch 6/15
# 165/165 [==============================] - 2s 10ms/step - loss: 4.0405 - val_loss: 4.1924
# Epoch 7/15
# 165/165 [==============================] - 2s 13ms/step - loss: 4.0110 - val_loss: 6.0622
# Epoch 8/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.8958 - val_loss: 4.9199
# Epoch 9/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.8688 - val_loss: 4.8022
# Epoch 10/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.7811 - val_loss: 6.3038
# Epoch 11/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.8577 - val_loss: 12.3905
# Epoch 12/15
# 165/165 [==============================] - 2s 9ms/step - loss: 3.8431 - val_loss: 7.3513
# Epoch 13/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.7058 - val_loss: 5.5179
# Epoch 14/15
# 165/165 [==============================] - 3s 17ms/step - loss: 3.7209 - val_loss: 4.1796
# Epoch 15/15
# 165/165 [==============================] - 3s 18ms/step - loss: 3.6319 - val_loss: 4.9739
# 183/183 [==============================] - 1s 2ms/step
#  the 650 samples have been concatenated
# Best Threshold= 4.429513
# fan_id_00 -6 dB 52 completed
# Epoch 1/15
# 165/165 [==============================] - 8s 13ms/step - loss: 24.9369 - val_loss: 1890.1432
# Epoch 2/15
# 165/165 [==============================] - 2s 9ms/step - loss: 4.8280 - val_loss: 5.8237
# Epoch 3/15
# 165/165 [==============================] - 2s 10ms/step - loss: 4.2510 - val_loss: 8.2779
# Epoch 4/15
# 165/165 [==============================] - 2s 13ms/step - loss: 4.0963 - val_loss: 7.9406
# Epoch 5/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.9594 - val_loss: 5.2859
# Epoch 6/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.9884 - val_loss: 4.0732
# Epoch 7/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.9228 - val_loss: 4.3289
# Epoch 8/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.8084 - val_loss: 5.2185
# Epoch 9/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.8202 - val_loss: 5.3601
# Epoch 10/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.8311 - val_loss: 6.5268
# Epoch 11/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.8190 - val_loss: 5.7189
# Epoch 12/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.7839 - val_loss: 3.9122
# Epoch 13/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.6457 - val_loss: 4.3056
# Epoch 14/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.6258 - val_loss: 4.1910
# Epoch 15/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.5412 - val_loss: 4.3868
# 183/183 [==============================] - 1s 2ms/step
#  the 650 samples have been concatenated
# Best Threshold= 5.739589
# fan_id_00 -6 dB 62 completed
# Epoch 1/15
# 165/165 [==============================] - 7s 13ms/step - loss: 29.4786 - val_loss: 3463.6406
# Epoch 2/15
# 165/165 [==============================] - 2s 11ms/step - loss: 4.5849 - val_loss: 4.9463
# Epoch 3/15
# 165/165 [==============================] - 2s 14ms/step - loss: 4.1463 - val_loss: 4.6035
# Epoch 4/15
# 165/165 [==============================] - 2s 12ms/step - loss: 3.9866 - val_loss: 5.0845
# Epoch 5/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.9250 - val_loss: 4.6011
# Epoch 6/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.7656 - val_loss: 3.9585
# Epoch 7/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.7496 - val_loss: 4.8297
# Epoch 8/15
# 165/165 [==============================] - 2s 9ms/step - loss: 3.8172 - val_loss: 4.8232
# Epoch 9/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.7191 - val_loss: 4.1895
# Epoch 10/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.6677 - val_loss: 4.2532
# Epoch 11/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.6219 - val_loss: 4.3475
# Epoch 12/15
# 165/165 [==============================] - 2s 12ms/step - loss: 3.6620 - val_loss: 4.0967
# Epoch 13/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.6705 - val_loss: 5.8296
# Epoch 14/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.6326 - val_loss: 4.9140
# Epoch 15/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.6164 - val_loss: 4.6465
# 183/183 [==============================] - 1s 2ms/step
#  the 650 samples have been concatenated
# Best Threshold= 5.113543
# fan_id_00 0 dB 42 completed
# Epoch 1/15
# 165/165 [==============================] - 9s 17ms/step - loss: 30.0484 - val_loss: 6.8809
# Epoch 2/15
# 165/165 [==============================] - 2s 10ms/step - loss: 4.5577 - val_loss: 6.8021
# Epoch 3/15
# 165/165 [==============================] - 2s 10ms/step - loss: 4.1532 - val_loss: 4.9504
# Epoch 4/15
# 165/165 [==============================] - 2s 9ms/step - loss: 3.9158 - val_loss: 4.0018
# Epoch 5/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.8411 - val_loss: 5.0084
# Epoch 6/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.7313 - val_loss: 4.0308
# Epoch 7/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.6591 - val_loss: 4.7359
# Epoch 8/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.6188 - val_loss: 4.8757
# Epoch 9/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.7225 - val_loss: 8.5269
# Epoch 10/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.6644 - val_loss: 4.8100
# Epoch 11/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.5447 - val_loss: 4.3795
# Epoch 12/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.4917 - val_loss: 4.2981
# Epoch 13/15
# 165/165 [==============================] - 2s 12ms/step - loss: 3.5071 - val_loss: 3.4772
# Epoch 14/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.4446 - val_loss: 6.6476
# Epoch 15/15
# 165/165 [==============================] - 2s 12ms/step - loss: 3.5335 - val_loss: 6.8403
# 183/183 [==============================] - 1s 4ms/step
#  the 650 samples have been concatenated
# Best Threshold= 6.576425
# fan_id_00 0 dB 52 completed
# Epoch 1/15
# 165/165 [==============================] - 8s 13ms/step - loss: 30.7831 - val_loss: 64.7762
# Epoch 2/15
# 165/165 [==============================] - 2s 10ms/step - loss: 5.1454 - val_loss: 6.4795
# Epoch 3/15
# 165/165 [==============================] - 2s 9ms/step - loss: 4.3437 - val_loss: 4.8981
# Epoch 4/15
# 165/165 [==============================] - 2s 9ms/step - loss: 4.1772 - val_loss: 4.3381
# Epoch 5/15
# 165/165 [==============================] - 2s 9ms/step - loss: 4.2716 - val_loss: 4.4436
# Epoch 6/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.8840 - val_loss: 4.8478
# Epoch 7/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.7758 - val_loss: 3.7222
# Epoch 8/15
# 165/165 [==============================] - 2s 9ms/step - loss: 3.7708 - val_loss: 4.6882
# Epoch 9/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.7024 - val_loss: 3.8837
# Epoch 10/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.7631 - val_loss: 4.0203
# Epoch 11/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.7210 - val_loss: 3.7123
# Epoch 12/15
# 165/165 [==============================] - 2s 9ms/step - loss: 3.5980 - val_loss: 3.8123
# Epoch 13/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.5620 - val_loss: 3.7870
# Epoch 14/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.5604 - val_loss: 4.0767
# Epoch 15/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.5923 - val_loss: 5.0034
# 183/183 [==============================] - 1s 2ms/step
#  the 650 samples have been concatenated
# Best Threshold= 3.611269
# fan_id_00 0 dB 62 completed
# Epoch 1/15
# 165/165 [==============================] - 7s 12ms/step - loss: 33.4471 - val_loss: 2968.3464
# Epoch 2/15
# 165/165 [==============================] - 2s 10ms/step - loss: 4.4413 - val_loss: 32.0759
# Epoch 3/15
# 165/165 [==============================] - 2s 11ms/step - loss: 4.1671 - val_loss: 3.7787
# Epoch 4/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.9507 - val_loss: 3.4810
# Epoch 5/15
# 165/165 [==============================] - 2s 12ms/step - loss: 3.8782 - val_loss: 3.7384
# Epoch 6/15
# 165/165 [==============================] - 2s 9ms/step - loss: 3.8358 - val_loss: 3.6750
# Epoch 7/15
# 165/165 [==============================] - 2s 9ms/step - loss: 3.8267 - val_loss: 3.8732
# Epoch 8/15
# 165/165 [==============================] - 2s 9ms/step - loss: 3.8496 - val_loss: 3.7562
# Epoch 9/15
# 165/165 [==============================] - 2s 9ms/step - loss: 3.5612 - val_loss: 3.3817
# Epoch 10/15
# 165/165 [==============================] - 2s 9ms/step - loss: 3.7348 - val_loss: 3.9108
# Epoch 11/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.5064 - val_loss: 3.4079
# Epoch 12/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.4738 - val_loss: 3.3769
# Epoch 13/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.4102 - val_loss: 3.8288
# Epoch 14/15
# 165/165 [==============================] - 2s 9ms/step - loss: 3.3535 - val_loss: 3.7468
# Epoch 15/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.3159 - val_loss: 3.3735
# 183/183 [==============================] - 1s 2ms/step
#  the 650 samples have been concatenated
# Best Threshold= 3.050695
# fan_id_00 6 dB 42 completed
# Epoch 1/15
# 165/165 [==============================] - 8s 21ms/step - loss: 34.7915 - val_loss: 35.5661
# Epoch 2/15
# 165/165 [==============================] - 2s 13ms/step - loss: 4.2031 - val_loss: 68.1073
# Epoch 3/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.6787 - val_loss: 3.9721
# Epoch 4/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.5636 - val_loss: 3.5008
# Epoch 5/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.4484 - val_loss: 3.5652
# Epoch 6/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.5040 - val_loss: 3.7806
# Epoch 7/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.4153 - val_loss: 3.9047
# Epoch 8/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.5593 - val_loss: 3.7204
# Epoch 9/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.5404 - val_loss: 4.1831
# Epoch 10/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.4234 - val_loss: 3.5998
# Epoch 11/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.4738 - val_loss: 4.5834
# Epoch 12/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.4621 - val_loss: 4.1678
# Epoch 13/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.4043 - val_loss: 3.6523
# Epoch 14/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.3589 - val_loss: 4.5396
# Epoch 15/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.8454 - val_loss: 4.5715
# 183/183 [==============================] - 1s 3ms/step
#  the 650 samples have been concatenated
# Best Threshold= 5.377420
# fan_id_00 6 dB 52 completed
# Epoch 1/15
# 165/165 [==============================] - 9s 13ms/step - loss: 32.3605 - val_loss: 613.7010
# Epoch 2/15
# 165/165 [==============================] - 2s 10ms/step - loss: 4.7767 - val_loss: 4.6036
# Epoch 3/15
# 165/165 [==============================] - 2s 9ms/step - loss: 4.0427 - val_loss: 3.7890
# Epoch 4/15
# 165/165 [==============================] - 2s 9ms/step - loss: 3.8107 - val_loss: 3.6050
# Epoch 5/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.6711 - val_loss: 4.2309
# Epoch 6/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.5597 - val_loss: 3.4824
# Epoch 7/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.5036 - val_loss: 4.4616
# Epoch 8/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.4778 - val_loss: 4.9601
# Epoch 9/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.5419 - val_loss: 3.9207
# Epoch 10/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.4280 - val_loss: 3.3766
# Epoch 11/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.3924 - val_loss: 3.4675
# Epoch 12/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.3489 - val_loss: 4.2574
# Epoch 13/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.3636 - val_loss: 3.3482
# Epoch 14/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.3471 - val_loss: 3.6075
# Epoch 15/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.2288 - val_loss: 3.3066
# 183/183 [==============================] - 1s 4ms/step
#  the 650 samples have been concatenated
# Best Threshold= 3.532321
# fan_id_00 6 dB 62 completed
# Epoch 1/15
# 165/165 [==============================] - 7s 11ms/step - loss: 20.4249 - val_loss: 438.9735
# Epoch 2/15
# 165/165 [==============================] - 2s 10ms/step - loss: 4.0497 - val_loss: 4.7571
# Epoch 3/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.7007 - val_loss: 4.1165
# Epoch 4/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.5594 - val_loss: 4.4542
# Epoch 5/15
# 165/165 [==============================] - 2s 12ms/step - loss: 3.4383 - val_loss: 3.5612
# Epoch 6/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.4992 - val_loss: 4.1274
# Epoch 7/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.4054 - val_loss: 4.2121
# Epoch 8/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.4101 - val_loss: 4.6064
# Epoch 9/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.4157 - val_loss: 4.1698
# Epoch 10/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.3753 - val_loss: 3.8219
# Epoch 11/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.3156 - val_loss: 5.2774
# Epoch 12/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.3065 - val_loss: 5.6819
# Epoch 13/15
# 165/165 [==============================] - 2s 12ms/step - loss: 3.3452 - val_loss: 5.9204
# Epoch 14/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.2563 - val_loss: 4.8594
# Epoch 15/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.1610 - val_loss: 3.7169
# 183/183 [==============================] - 1s 2ms/step
#  the 650 samples have been concatenated
# Best Threshold= 3.047859
# fan_id_02 -6 dB 42 completed
# Epoch 1/15
# 165/165 [==============================] - 7s 13ms/step - loss: 21.5903 - val_loss: 60.3633
# Epoch 2/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.7653 - val_loss: 6.5716
# Epoch 3/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.6546 - val_loss: 4.0314
# Epoch 4/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.5343 - val_loss: 6.3360
# Epoch 5/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.4866 - val_loss: 4.1542
# Epoch 6/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.3757 - val_loss: 4.8458
# Epoch 7/15
# 165/165 [==============================] - 2s 9ms/step - loss: 3.3931 - val_loss: 4.0377
# Epoch 8/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.3427 - val_loss: 4.2785
# Epoch 9/15
# 165/165 [==============================] - 2s 12ms/step - loss: 3.3374 - val_loss: 3.8948
# Epoch 10/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.3578 - val_loss: 3.9133
# Epoch 11/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.4542 - val_loss: 5.2318
# Epoch 12/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.3489 - val_loss: 4.1471
# Epoch 13/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.2100 - val_loss: 3.9616
# Epoch 14/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.2219 - val_loss: 4.3633
# Epoch 15/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.1633 - val_loss: 3.9498
# 183/183 [==============================] - 1s 4ms/step
#  the 650 samples have been concatenated
# Best Threshold= 4.220134
# fan_id_02 -6 dB 52 completed
# Epoch 1/15
# 165/165 [==============================] - 9s 12ms/step - loss: 20.1291 - val_loss: 7216.9053
# Epoch 2/15
# 165/165 [==============================] - 2s 10ms/step - loss: 4.3118 - val_loss: 5.1508
# Epoch 3/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.7213 - val_loss: 5.1430
# Epoch 4/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.5930 - val_loss: 3.5521
# Epoch 5/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.4922 - val_loss: 3.5871
# Epoch 6/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.5492 - val_loss: 4.0318
# Epoch 7/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.5494 - val_loss: 4.7717
# Epoch 8/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.5194 - val_loss: 3.4889
# Epoch 9/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.5069 - val_loss: 4.3917
# Epoch 10/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.4057 - val_loss: 3.6200
# Epoch 11/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.3649 - val_loss: 3.5440
# Epoch 12/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.4351 - val_loss: 8.9474
# Epoch 13/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.3515 - val_loss: 4.9577
# Epoch 14/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.3361 - val_loss: 5.7868
# Epoch 15/15
# 165/165 [==============================] - 2s 12ms/step - loss: 3.2929 - val_loss: 6.0674
# 183/183 [==============================] - 1s 3ms/step
#  the 650 samples have been concatenated
# Best Threshold= 6.263259
# fan_id_02 -6 dB 62 completed
# Epoch 1/15
# 165/165 [==============================] - 7s 13ms/step - loss: 23.2550 - val_loss: 3840.5781
# Epoch 2/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.9281 - val_loss: 47.1312
# Epoch 3/15
# 165/165 [==============================] - 2s 12ms/step - loss: 3.4272 - val_loss: 5.0190
# Epoch 4/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.3828 - val_loss: 3.2028
# Epoch 5/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.4397 - val_loss: 4.2685
# Epoch 6/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.2329 - val_loss: 3.1740
# Epoch 7/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.2220 - val_loss: 3.1082
# Epoch 8/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.1925 - val_loss: 3.5844
# Epoch 9/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.1785 - val_loss: 3.8310
# Epoch 10/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.1668 - val_loss: 3.1618
# Epoch 11/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.1981 - val_loss: 3.2538
# Epoch 12/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.2042 - val_loss: 4.3455
# Epoch 13/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.2536 - val_loss: 3.1905
# Epoch 14/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.1322 - val_loss: 3.4055
# Epoch 15/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.1116 - val_loss: 4.4023
# 183/183 [==============================] - 1s 3ms/step
#  the 650 samples have been concatenated
# Best Threshold= 4.748595
# fan_id_02 0 dB 42 completed
# Epoch 1/15
# 165/165 [==============================] - 9s 13ms/step - loss: 22.3723 - val_loss: 413.8901
# Epoch 2/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.5555 - val_loss: 5.6136
# Epoch 3/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.2311 - val_loss: 3.5157
# Epoch 4/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.2814 - val_loss: 5.0880
# Epoch 5/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.2738 - val_loss: 3.9788
# Epoch 6/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.3359 - val_loss: 3.7059
# Epoch 7/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.1670 - val_loss: 4.2751
# Epoch 8/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.2431 - val_loss: 6.0037
# Epoch 9/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.3082 - val_loss: 3.6748
# Epoch 10/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.1520 - val_loss: 3.1797
# Epoch 11/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.1436 - val_loss: 3.6406
# Epoch 12/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.1122 - val_loss: 3.5150
# Epoch 13/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.1473 - val_loss: 4.0670
# Epoch 14/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.1068 - val_loss: 3.8355
# Epoch 15/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.1769 - val_loss: 4.0338
# 183/183 [==============================] - 1s 2ms/step
#  the 650 samples have been concatenated
# Best Threshold= 4.025685
# fan_id_02 0 dB 52 completed
# Epoch 1/15
# 165/165 [==============================] - 9s 12ms/step - loss: 22.5274 - val_loss: 26.7380
# Epoch 2/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.7359 - val_loss: 46.1624
# Epoch 3/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.3653 - val_loss: 3.4223
# Epoch 4/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.2426 - val_loss: 3.5638
# Epoch 5/15
# 165/165 [==============================] - 2s 12ms/step - loss: 3.2312 - val_loss: 3.6758
# Epoch 6/15
# 165/165 [==============================] - 2s 15ms/step - loss: 3.1851 - val_loss: 3.3720
# Epoch 7/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.1771 - val_loss: 3.6493
# Epoch 8/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.2307 - val_loss: 4.2172
# Epoch 9/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.1565 - val_loss: 4.2826
# Epoch 10/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.4075 - val_loss: 7.0597
# Epoch 11/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.1403 - val_loss: 3.5296
# Epoch 12/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.1064 - val_loss: 3.5297
# Epoch 13/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.0708 - val_loss: 3.4158
# Epoch 14/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.0460 - val_loss: 3.1239
# Epoch 15/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.0308 - val_loss: 3.1037
# 183/183 [==============================] - 1s 3ms/step
#  the 650 samples have been concatenated
# Best Threshold= 3.473519
# fan_id_02 0 dB 62 completed
# Epoch 1/15
# 165/165 [==============================] - 9s 17ms/step - loss: 23.6028 - val_loss: 42.0686
# Epoch 2/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.5055 - val_loss: 25.1464
# Epoch 3/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.0671 - val_loss: 3.3865
# Epoch 4/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.0716 - val_loss: 3.2710
# Epoch 5/15
# 165/165 [==============================] - 2s 10ms/step - loss: 2.9601 - val_loss: 2.9791
# Epoch 6/15
# 165/165 [==============================] - 2s 10ms/step - loss: 2.9881 - val_loss: 2.9644
# Epoch 7/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.0053 - val_loss: 2.9098
# Epoch 8/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.0149 - val_loss: 3.3606
# Epoch 9/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.0310 - val_loss: 5.6042
# Epoch 10/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.0139 - val_loss: 3.4063
# Epoch 11/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.0385 - val_loss: 2.9968
# Epoch 12/15
# 165/165 [==============================] - 2s 10ms/step - loss: 2.9303 - val_loss: 3.4799
# Epoch 13/15
# 165/165 [==============================] - 2s 10ms/step - loss: 2.9344 - val_loss: 3.4420
# Epoch 14/15
# 165/165 [==============================] - 2s 10ms/step - loss: 2.9442 - val_loss: 3.0620
# Epoch 15/15
# 165/165 [==============================] - 2s 10ms/step - loss: 2.9503 - val_loss: 3.4208
# 183/183 [==============================] - 1s 4ms/step
#  the 650 samples have been concatenated
# Best Threshold= 4.077532
# fan_id_02 6 dB 42 completed
# Epoch 1/15
# 165/165 [==============================] - 8s 12ms/step - loss: 23.3405 - val_loss: 40.5617
# Epoch 2/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.6590 - val_loss: 8.0947
# Epoch 3/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.1191 - val_loss: 3.7650
# Epoch 4/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.0915 - val_loss: 3.0860
# Epoch 5/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.0153 - val_loss: 3.3505
# Epoch 6/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.0345 - val_loss: 3.5427
# Epoch 7/15
# 165/165 [==============================] - 2s 10ms/step - loss: 2.9660 - val_loss: 3.6218
# Epoch 8/15
# 165/165 [==============================] - 2s 10ms/step - loss: 2.9825 - val_loss: 2.8932
# Epoch 9/15
# 165/165 [==============================] - 2s 10ms/step - loss: 2.9967 - val_loss: 4.9162
# Epoch 10/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.0297 - val_loss: 4.3572
# Epoch 11/15
# 165/165 [==============================] - 2s 10ms/step - loss: 2.9383 - val_loss: 2.9185
# Epoch 12/15
# 165/165 [==============================] - 2s 11ms/step - loss: 2.9725 - val_loss: 3.2234
# Epoch 13/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.0019 - val_loss: 2.9688
# Epoch 14/15
# 165/165 [==============================] - 3s 17ms/step - loss: 2.8894 - val_loss: 4.0188
# Epoch 15/15
# 165/165 [==============================] - 2s 14ms/step - loss: 2.9321 - val_loss: 3.8605
# 183/183 [==============================] - 1s 4ms/step
#  the 650 samples have been concatenated
# Best Threshold= 4.281374
# fan_id_02 6 dB 52 completed
# Epoch 1/15
# 165/165 [==============================] - 8s 15ms/step - loss: 23.2164 - val_loss: 15863.6543
# Epoch 2/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.3773 - val_loss: 7.0364
# Epoch 3/15
# 165/165 [==============================] - 2s 12ms/step - loss: 3.0722 - val_loss: 5.4268
# Epoch 4/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.0709 - val_loss: 4.5822
# Epoch 5/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.0928 - val_loss: 3.2142
# Epoch 6/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.0427 - val_loss: 4.6116
# Epoch 7/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.0142 - val_loss: 3.7495
# Epoch 8/15
# 165/165 [==============================] - 2s 11ms/step - loss: 2.9890 - val_loss: 3.0887
# Epoch 9/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.0312 - val_loss: 4.1653
# Epoch 10/15
# 165/165 [==============================] - 2s 14ms/step - loss: 2.9635 - val_loss: 3.4286
# Epoch 11/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.0429 - val_loss: 10.5093
# Epoch 12/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.0136 - val_loss: 4.4984
# Epoch 13/15
# 165/165 [==============================] - 2s 11ms/step - loss: 2.9434 - val_loss: 3.0560
# Epoch 14/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.0211 - val_loss: 3.0865
# Epoch 15/15
# 165/165 [==============================] - 2s 11ms/step - loss: 2.9024 - val_loss: 2.9032
# 183/183 [==============================] - 1s 3ms/step
#  the 650 samples have been concatenated
# Best Threshold= 3.235050
# fan_id_02 6 dB 62 completed
# Epoch 1/15
# 165/165 [==============================] - 8s 15ms/step - loss: 22.5394 - val_loss: 69.5219
# Epoch 2/15
# 165/165 [==============================] - 2s 10ms/step - loss: 4.2891 - val_loss: 5.0955
# Epoch 3/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.9933 - val_loss: 4.3336
# Epoch 4/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.9156 - val_loss: 4.3693
# Epoch 5/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.7769 - val_loss: 5.1017
# Epoch 6/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.8719 - val_loss: 4.9168
# Epoch 7/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.8885 - val_loss: 3.8660
# Epoch 8/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.7273 - val_loss: 5.2112
# Epoch 9/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.5859 - val_loss: 5.0713
# Epoch 10/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.6087 - val_loss: 3.9562
# Epoch 11/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.5957 - val_loss: 3.9153
# Epoch 12/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.5078 - val_loss: 3.9070
# Epoch 13/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.4808 - val_loss: 3.7850
# Epoch 14/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.5787 - val_loss: 4.0389
# Epoch 15/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.4915 - val_loss: 12.8988
# 183/183 [==============================] - 1s 2ms/step
#  the 650 samples have been concatenated
# Best Threshold= 11.770908
# fan_id_04 -6 dB 42 completed
# Epoch 1/15
# 165/165 [==============================] - 9s 11ms/step - loss: 21.5698 - val_loss: 39.4912
# Epoch 2/15
# 165/165 [==============================] - 2s 10ms/step - loss: 5.1146 - val_loss: 4.6286
# Epoch 3/15
# 165/165 [==============================] - 2s 10ms/step - loss: 4.2081 - val_loss: 9.6044
# Epoch 4/15
# 165/165 [==============================] - 2s 10ms/step - loss: 4.2311 - val_loss: 5.2280
# Epoch 5/15
# 165/165 [==============================] - 2s 12ms/step - loss: 3.9231 - val_loss: 3.5460
# Epoch 6/15
# 165/165 [==============================] - 2s 15ms/step - loss: 3.8741 - val_loss: 4.1831
# Epoch 7/15
# 165/165 [==============================] - 2s 12ms/step - loss: 3.8204 - val_loss: 4.3569
# Epoch 8/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.7887 - val_loss: 3.7045
# Epoch 9/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.7425 - val_loss: 6.8085
# Epoch 10/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.7378 - val_loss: 4.8559
# Epoch 11/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.6168 - val_loss: 3.5536
# Epoch 12/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.6027 - val_loss: 3.5628
# Epoch 13/15
# 165/165 [==============================] - 2s 12ms/step - loss: 3.5316 - val_loss: 4.2089
# Epoch 14/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.5826 - val_loss: 4.9526
# Epoch 15/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.5029 - val_loss: 4.8716
# 183/183 [==============================] - 1s 4ms/step
#  the 650 samples have been concatenated
# Best Threshold= 5.268633
# fan_id_04 -6 dB 52 completed
# Epoch 1/15
# 165/165 [==============================] - 8s 11ms/step - loss: 22.6545 - val_loss: 17.9167
# Epoch 2/15
# 165/165 [==============================] - 2s 10ms/step - loss: 4.7238 - val_loss: 6.0618
# Epoch 3/15
# 165/165 [==============================] - 2s 10ms/step - loss: 4.2313 - val_loss: 5.7591
# Epoch 4/15
# 165/165 [==============================] - 2s 10ms/step - loss: 4.0985 - val_loss: 4.8142
# Epoch 5/15
# 165/165 [==============================] - 3s 17ms/step - loss: 4.0784 - val_loss: 6.5581
# Epoch 6/15
# 165/165 [==============================] - 3s 18ms/step - loss: 3.9169 - val_loss: 4.0990
# Epoch 7/15
# 165/165 [==============================] - 3s 15ms/step - loss: 3.9504 - val_loss: 4.6524
# Epoch 8/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.8106 - val_loss: 5.8092
# Epoch 9/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.7934 - val_loss: 3.8130
# Epoch 10/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.6839 - val_loss: 3.9810
# Epoch 11/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.6837 - val_loss: 5.8125
# Epoch 12/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.7021 - val_loss: 4.2967
# Epoch 13/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.5576 - val_loss: 4.5284
# Epoch 14/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.5479 - val_loss: 4.1875
# Epoch 15/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.4466 - val_loss: 3.4741
# 183/183 [==============================] - 1s 2ms/step
#  the 650 samples have been concatenated
# Best Threshold= 2.954024
# fan_id_04 -6 dB 62 completed
# Epoch 1/15
# 165/165 [==============================] - 7s 13ms/step - loss: 25.5400 - val_loss: 112.9821
# Epoch 2/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.7567 - val_loss: 20.7925
# Epoch 3/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.4010 - val_loss: 7.8164
# Epoch 4/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.4330 - val_loss: 4.7520
# Epoch 5/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.2535 - val_loss: 4.0818
# Epoch 6/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.2262 - val_loss: 4.0142
# Epoch 7/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.2016 - val_loss: 3.5161
# Epoch 8/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.2382 - val_loss: 4.0762
# Epoch 9/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.3032 - val_loss: 46.3465
# Epoch 10/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.2541 - val_loss: 4.4849
# Epoch 11/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.1892 - val_loss: 4.0658
# Epoch 12/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.1544 - val_loss: 5.0103
# Epoch 13/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.1260 - val_loss: 4.5432
# Epoch 14/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.0804 - val_loss: 4.2727
# Epoch 15/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.0851 - val_loss: 4.0470
# 183/183 [==============================] - 1s 2ms/step
#  the 650 samples have been concatenated
# Best Threshold= 4.143676
# fan_id_04 0 dB 42 completed
# Epoch 1/15
# 165/165 [==============================] - 7s 13ms/step - loss: 25.5625 - val_loss: 41.1996
# Epoch 2/15
# 165/165 [==============================] - 2s 15ms/step - loss: 3.8091 - val_loss: 5.1446
# Epoch 3/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.4586 - val_loss: 5.2632
# Epoch 4/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.3754 - val_loss: 3.7330
# Epoch 5/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.2388 - val_loss: 3.7969
# Epoch 6/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.3661 - val_loss: 3.2697
# Epoch 7/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.3534 - val_loss: 3.7892
# Epoch 8/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.2948 - val_loss: 4.4512
# Epoch 9/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.1874 - val_loss: 3.2239
# Epoch 10/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.2476 - val_loss: 3.9672
# Epoch 11/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.1681 - val_loss: 3.8948
# Epoch 12/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.1952 - val_loss: 3.7841
# Epoch 13/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.1623 - val_loss: 3.9472
# Epoch 14/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.3421 - val_loss: 4.8671
# Epoch 15/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.1612 - val_loss: 4.3143
# 183/183 [==============================] - 1s 3ms/step
#  the 650 samples have been concatenated
# Best Threshold= 4.442412
# fan_id_04 0 dB 52 completed
# Epoch 1/15
# 165/165 [==============================] - 9s 12ms/step - loss: 25.5842 - val_loss: 427.2054
# Epoch 2/15
# 165/165 [==============================] - 2s 11ms/step - loss: 4.0473 - val_loss: 5.6274
# Epoch 3/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.6973 - val_loss: 19.5768
# Epoch 4/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.4601 - val_loss: 4.2453
# Epoch 5/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.4830 - val_loss: 5.0518
# Epoch 6/15
# 165/165 [==============================] - 2s 15ms/step - loss: 3.6833 - val_loss: 4.8531
# Epoch 7/15
# 165/165 [==============================] - 2s 12ms/step - loss: 3.4055 - val_loss: 5.3019
# Epoch 8/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.3637 - val_loss: 3.9438
# Epoch 9/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.2682 - val_loss: 3.3193
# Epoch 10/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.2210 - val_loss: 3.2414
# Epoch 11/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.1913 - val_loss: 3.7826
# Epoch 12/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.3112 - val_loss: 5.1773
# Epoch 13/15
# 165/165 [==============================] - 2s 15ms/step - loss: 3.1466 - val_loss: 3.4703
# Epoch 14/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.1085 - val_loss: 3.3262
# Epoch 15/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.1599 - val_loss: 3.2986
# 183/183 [==============================] - 1s 3ms/step
#  the 650 samples have been concatenated
# Best Threshold= 3.273478
# fan_id_04 0 dB 62 completed
# Epoch 1/15
# 165/165 [==============================] - 7s 11ms/step - loss: 26.6015 - val_loss: 8.4757
# Epoch 2/15
# 165/165 [==============================] - 2s 11ms/step - loss: 4.4428 - val_loss: 5.6822
# Epoch 3/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.3553 - val_loss: 3.9599
# Epoch 4/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.0763 - val_loss: 2.9556
# Epoch 5/15
# 165/165 [==============================] - 2s 10ms/step - loss: 2.9915 - val_loss: 3.1564
# Epoch 6/15
# 165/165 [==============================] - 2s 12ms/step - loss: 2.9683 - val_loss: 3.7394
# Epoch 7/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.1160 - val_loss: 3.3588
# Epoch 8/15
# 165/165 [==============================] - 2s 12ms/step - loss: 3.0594 - val_loss: 3.0678
# Epoch 9/15
# 165/165 [==============================] - 2s 10ms/step - loss: 2.9208 - val_loss: 2.9570
# Epoch 10/15
# 165/165 [==============================] - 2s 15ms/step - loss: 2.9156 - val_loss: 2.9071
# Epoch 11/15
# 165/165 [==============================] - 2s 13ms/step - loss: 2.9254 - val_loss: 3.1098
# Epoch 12/15
# 165/165 [==============================] - 2s 10ms/step - loss: 2.9393 - val_loss: 3.1661
# Epoch 13/15
# 165/165 [==============================] - 2s 10ms/step - loss: 2.9710 - val_loss: 2.9344
# Epoch 14/15
# 165/165 [==============================] - 2s 10ms/step - loss: 2.9892 - val_loss: 3.0672
# Epoch 15/15
# 165/165 [==============================] - 2s 10ms/step - loss: 2.9692 - val_loss: 3.0843
# 183/183 [==============================] - 1s 2ms/step
#  the 650 samples have been concatenated
# Best Threshold= 3.361518
# fan_id_04 6 dB 42 completed
# Epoch 1/15
# 165/165 [==============================] - 10s 12ms/step - loss: 26.0790 - val_loss: 1272.0197
# Epoch 2/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.8231 - val_loss: 5.3416
# Epoch 3/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.3519 - val_loss: 3.4518
# Epoch 4/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.0735 - val_loss: 3.2809
# Epoch 5/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.0580 - val_loss: 3.0090
# Epoch 6/15
# 165/165 [==============================] - 2s 12ms/step - loss: 3.0515 - val_loss: 11.4508
# Epoch 7/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.0011 - val_loss: 4.1604
# Epoch 8/15
# 165/165 [==============================] - 2s 13ms/step - loss: 2.9619 - val_loss: 4.4309
# Epoch 9/15
# 165/165 [==============================] - 2s 10ms/step - loss: 2.9370 - val_loss: 3.2798
# Epoch 10/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.0712 - val_loss: 3.9994
# Epoch 11/15
# 165/165 [==============================] - 2s 10ms/step - loss: 2.9250 - val_loss: 3.4322
# Epoch 12/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.1572 - val_loss: 6.5261
# Epoch 13/15
# 165/165 [==============================] - 2s 10ms/step - loss: 2.9581 - val_loss: 2.9713
# Epoch 14/15
# 165/165 [==============================] - 2s 12ms/step - loss: 2.8887 - val_loss: 3.1458
# Epoch 15/15
# 165/165 [==============================] - 2s 14ms/step - loss: 2.9296 - val_loss: 2.9804
# 183/183 [==============================] - 1s 3ms/step
#  the 650 samples have been concatenated
# Best Threshold= 3.144301
# fan_id_04 6 dB 52 completed
# Epoch 1/15
# 165/165 [==============================] - 8s 12ms/step - loss: 26.8706 - val_loss: 17153.2715
# Epoch 2/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.3736 - val_loss: 8.1787
# Epoch 3/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.0706 - val_loss: 3.0501
# Epoch 4/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.0522 - val_loss: 4.7736
# Epoch 5/15
# 165/165 [==============================] - 2s 14ms/step - loss: 2.9272 - val_loss: 2.9833
# Epoch 6/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.0923 - val_loss: 3.3718
# Epoch 7/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.0963 - val_loss: 3.3448
# Epoch 8/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.0454 - val_loss: 14.1997
# Epoch 9/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.1911 - val_loss: 3.2471
# Epoch 10/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.0398 - val_loss: 4.4102
# Epoch 11/15
# 165/165 [==============================] - 2s 11ms/step - loss: 2.9921 - val_loss: 2.9257
# Epoch 12/15
# 165/165 [==============================] - 2s 13ms/step - loss: 2.9378 - val_loss: 3.0691
# Epoch 13/15
# 165/165 [==============================] - 2s 13ms/step - loss: 2.9079 - val_loss: 3.3325
# Epoch 14/15
# 165/165 [==============================] - 2s 10ms/step - loss: 2.9137 - val_loss: 3.5078
# Epoch 15/15
# 165/165 [==============================] - 2s 10ms/step - loss: 2.8752 - val_loss: 2.9499
# 183/183 [==============================] - 1s 3ms/step
#  the 650 samples have been concatenated
# Best Threshold= 3.386605
# fan_id_04 6 dB 62 completed
# Epoch 1/15
# 165/165 [==============================] - 7s 12ms/step - loss: 24.2667 - val_loss: 757.6927
# Epoch 2/15
# 165/165 [==============================] - 2s 13ms/step - loss: 4.2596 - val_loss: 4.2751
# Epoch 3/15
# 165/165 [==============================] - 3s 15ms/step - loss: 3.9195 - val_loss: 4.5040
# Epoch 4/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.8951 - val_loss: 5.0758
# Epoch 5/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.8722 - val_loss: 5.6937
# Epoch 6/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.7285 - val_loss: 4.8989
# Epoch 7/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.7449 - val_loss: 4.7600
# Epoch 8/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.6183 - val_loss: 4.1034
# Epoch 9/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.5890 - val_loss: 6.9148
# Epoch 10/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.5429 - val_loss: 3.5606
# Epoch 11/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.5168 - val_loss: 3.3672
# Epoch 12/15
# 165/165 [==============================] - 2s 12ms/step - loss: 3.4370 - val_loss: 5.3422
# Epoch 13/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.4441 - val_loss: 6.3387
# Epoch 14/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.4271 - val_loss: 4.1098
# Epoch 15/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.3290 - val_loss: 9.6064
# 183/183 [==============================] - 1s 2ms/step
#  the 650 samples have been concatenated
# Best Threshold= 9.290141
# fan_id_06 -6 dB 42 completed
# Epoch 1/15
# 165/165 [==============================] - 8s 18ms/step - loss: 23.5510 - val_loss: 20.4491
# Epoch 2/15
# 165/165 [==============================] - 2s 14ms/step - loss: 5.2328 - val_loss: 5.2890
# Epoch 3/15
# 165/165 [==============================] - 2s 14ms/step - loss: 4.4097 - val_loss: 4.9193
# Epoch 4/15
# 165/165 [==============================] - 2s 13ms/step - loss: 4.1097 - val_loss: 5.1793
# Epoch 5/15
# 165/165 [==============================] - 2s 11ms/step - loss: 4.1253 - val_loss: 5.0884
# Epoch 6/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.9188 - val_loss: 3.8809
# Epoch 7/15
# 165/165 [==============================] - 2s 12ms/step - loss: 3.8624 - val_loss: 4.0584
# Epoch 8/15
# 165/165 [==============================] - 2s 15ms/step - loss: 3.8538 - val_loss: 4.2239
# Epoch 9/15
# 165/165 [==============================] - 2s 12ms/step - loss: 3.6797 - val_loss: 6.2517
# Epoch 10/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.6358 - val_loss: 8.0112
# Epoch 11/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.5707 - val_loss: 3.5907
# Epoch 12/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.4566 - val_loss: 4.0222
# Epoch 13/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.3703 - val_loss: 4.1195
# Epoch 14/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.4091 - val_loss: 4.2169
# Epoch 15/15
# 165/165 [==============================] - 2s 15ms/step - loss: 3.3477 - val_loss: 4.5222
# 183/183 [==============================] - 1s 4ms/step
#  the 650 samples have been concatenated
# Best Threshold= 4.987055
# fan_id_06 -6 dB 52 completed
# Epoch 1/15
# 165/165 [==============================] - 8s 13ms/step - loss: 23.2640 - val_loss: 72.8841
# Epoch 2/15
# 165/165 [==============================] - 2s 11ms/step - loss: 4.6973 - val_loss: 11.5276
# Epoch 3/15
# 165/165 [==============================] - 2s 11ms/step - loss: 4.1276 - val_loss: 5.6568
# Epoch 4/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.8898 - val_loss: 4.4990
# Epoch 5/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.7682 - val_loss: 3.8842
# Epoch 6/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.8881 - val_loss: 4.9070
# Epoch 7/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.7252 - val_loss: 4.7141
# Epoch 8/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.6422 - val_loss: 3.9790
# Epoch 9/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.6075 - val_loss: 3.9134
# Epoch 10/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.8523 - val_loss: 5.2116
# Epoch 11/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.5428 - val_loss: 3.6407
# Epoch 12/15
# 165/165 [==============================] - 2s 12ms/step - loss: 3.4878 - val_loss: 4.5044
# Epoch 13/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.4273 - val_loss: 6.0179
# Epoch 14/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.3871 - val_loss: 4.7673
# Epoch 15/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.3919 - val_loss: 5.1882
# 183/183 [==============================] - 1s 3ms/step
#  the 650 samples have been concatenated
# Best Threshold= 5.551434
# fan_id_06 -6 dB 62 completed
# Epoch 1/15
# 165/165 [==============================] - 8s 16ms/step - loss: 26.6747 - val_loss: 17.4210
# Epoch 2/15
# 165/165 [==============================] - 2s 14ms/step - loss: 4.3502 - val_loss: 73.0057
# Epoch 3/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.8380 - val_loss: 4.5895
# Epoch 4/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.5858 - val_loss: 3.7940
# Epoch 5/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.5112 - val_loss: 3.7559
# Epoch 6/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.4266 - val_loss: 4.3026
# Epoch 7/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.4221 - val_loss: 3.2146
# Epoch 8/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.3724 - val_loss: 4.7361
# Epoch 9/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.3615 - val_loss: 3.5587
# Epoch 10/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.2906 - val_loss: 3.3885
# Epoch 11/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.4943 - val_loss: 4.0520
# Epoch 12/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.3491 - val_loss: 3.5286
# Epoch 13/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.2904 - val_loss: 6.1778
# Epoch 14/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.2231 - val_loss: 5.3844
# Epoch 15/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.1852 - val_loss: 3.9785
# 183/183 [==============================] - 1s 3ms/step
#  the 650 samples have been concatenated
# Best Threshold= 4.920572
# fan_id_06 0 dB 42 completed
# Epoch 1/15
# 165/165 [==============================] - 9s 15ms/step - loss: 25.9523 - val_loss: 105.7517
# Epoch 2/15
# 165/165 [==============================] - 2s 11ms/step - loss: 4.0469 - val_loss: 4.8378
# Epoch 3/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.8106 - val_loss: 86.5845
# Epoch 4/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.6607 - val_loss: 4.5171
# Epoch 5/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.4648 - val_loss: 4.6994
# Epoch 6/15
# 165/165 [==============================] - 2s 12ms/step - loss: 3.4451 - val_loss: 3.9160
# Epoch 7/15
# 165/165 [==============================] - 2s 15ms/step - loss: 3.5959 - val_loss: 4.5324
# Epoch 8/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.4592 - val_loss: 3.5100
# Epoch 9/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.4059 - val_loss: 4.5204
# Epoch 10/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.3619 - val_loss: 3.8262
# Epoch 11/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.4624 - val_loss: 4.4313
# Epoch 12/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.3936 - val_loss: 3.5924
# Epoch 13/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.3420 - val_loss: 4.5643
# Epoch 14/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.3499 - val_loss: 3.8584
# Epoch 15/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.2595 - val_loss: 3.9313
# 183/183 [==============================] - 1s 3ms/step
#  the 650 samples have been concatenated
# Best Threshold= 4.662003
# fan_id_06 0 dB 52 completed
# Epoch 1/15
# 165/165 [==============================] - 8s 12ms/step - loss: 26.7839 - val_loss: 7404.7905
# Epoch 2/15
# 165/165 [==============================] - 2s 11ms/step - loss: 4.1894 - val_loss: 86.4863
# Epoch 3/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.8012 - val_loss: 4.2038
# Epoch 4/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.7810 - val_loss: 4.2427
# Epoch 5/15
# 165/165 [==============================] - 3s 15ms/step - loss: 3.5153 - val_loss: 3.9031
# Epoch 6/15
# 165/165 [==============================] - 3s 17ms/step - loss: 3.5639 - val_loss: 4.2079
# Epoch 7/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.6248 - val_loss: 3.9818
# Epoch 8/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.4976 - val_loss: 3.6918
# Epoch 9/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.4303 - val_loss: 3.3957
# Epoch 10/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.3117 - val_loss: 3.1845
# Epoch 11/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.3076 - val_loss: 3.5375
# Epoch 12/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.3184 - val_loss: 4.2499
# Epoch 13/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.3474 - val_loss: 4.1770
# Epoch 14/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.2971 - val_loss: 4.2003
# Epoch 15/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.3783 - val_loss: 4.3372
# 183/183 [==============================] - 1s 3ms/step
#  the 650 samples have been concatenated
# Best Threshold= 5.379267
# fan_id_06 0 dB 62 completed
# Epoch 1/15
# 165/165 [==============================] - 8s 16ms/step - loss: 28.3668 - val_loss: 447.8332
# Epoch 2/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.4095 - val_loss: 11.1843
# Epoch 3/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.0373 - val_loss: 3.4099
# Epoch 4/15
# 165/165 [==============================] - 2s 10ms/step - loss: 2.9189 - val_loss: 3.2551
# Epoch 5/15
# 165/165 [==============================] - 2s 11ms/step - loss: 2.9751 - val_loss: 3.1936
# Epoch 6/15
# 165/165 [==============================] - 2s 11ms/step - loss: 2.9813 - val_loss: 3.8731
# Epoch 7/15
# 165/165 [==============================] - 2s 11ms/step - loss: 2.9959 - val_loss: 8.9025
# Epoch 8/15
# 165/165 [==============================] - 2s 13ms/step - loss: 2.9143 - val_loss: 4.6772
# Epoch 9/15
# 165/165 [==============================] - 2s 14ms/step - loss: 2.8739 - val_loss: 3.2436
# Epoch 10/15
# 165/165 [==============================] - 2s 11ms/step - loss: 2.8836 - val_loss: 3.8231
# Epoch 11/15
# 165/165 [==============================] - 2s 11ms/step - loss: 2.8806 - val_loss: 3.1514
# Epoch 12/15
# 165/165 [==============================] - 2s 11ms/step - loss: 2.9047 - val_loss: 3.4631
# Epoch 13/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.1436 - val_loss: 5.3020
# Epoch 14/15
# 165/165 [==============================] - 2s 11ms/step - loss: 2.8533 - val_loss: 3.2659
# Epoch 15/15
# 165/165 [==============================] - 2s 13ms/step - loss: 2.8557 - val_loss: 3.1542
# 183/183 [==============================] - 1s 4ms/step
#  the 650 samples have been concatenated
# Best Threshold= 3.747004
# fan_id_06 6 dB 42 completed
# Epoch 1/15
# 165/165 [==============================] - 8s 12ms/step - loss: 30.5431 - val_loss: 81.4533
# Epoch 2/15
# 165/165 [==============================] - 2s 11ms/step - loss: 4.2845 - val_loss: 14.3101
# Epoch 3/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.4946 - val_loss: 5.6398
# Epoch 4/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.3373 - val_loss: 3.2153
# Epoch 5/15
# 165/165 [==============================] - 2s 14ms/step - loss: 3.1877 - val_loss: 3.2912
# Epoch 6/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.1027 - val_loss: 3.3288
# Epoch 7/15
# 165/165 [==============================] - 2s 10ms/step - loss: 3.2898 - val_loss: 3.1659
# Epoch 8/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.0335 - val_loss: 3.1564
# Epoch 9/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.0117 - val_loss: 3.2283
# Epoch 10/15
# 165/165 [==============================] - 2s 11ms/step - loss: 2.9785 - val_loss: 3.0970
# Epoch 11/15
# 165/165 [==============================] - 2s 12ms/step - loss: 2.9717 - val_loss: 3.1848
# Epoch 12/15
# 165/165 [==============================] - 2s 14ms/step - loss: 2.9300 - val_loss: 3.4535
# Epoch 13/15
# 165/165 [==============================] - 2s 14ms/step - loss: 2.9253 - val_loss: 3.6545
# Epoch 14/15
# 165/165 [==============================] - 2s 10ms/step - loss: 2.8990 - val_loss: 3.1256
# Epoch 15/15
# 165/165 [==============================] - 2s 10ms/step - loss: 2.9252 - val_loss: 3.3070
# 183/183 [==============================] - 1s 3ms/step
#  the 650 samples have been concatenated
# Best Threshold= 3.776434
# fan_id_06 6 dB 52 completed
# Epoch 1/15
# 165/165 [==============================] - 10s 17ms/step - loss: 28.5059 - val_loss: 7.1635
# Epoch 2/15
# 165/165 [==============================] - 2s 13ms/step - loss: 3.5708 - val_loss: 7.8234
# Epoch 3/15
# 165/165 [==============================] - 2s 11ms/step - loss: 3.5657 - val_loss: 10.4484
# Epoch 4/15
# 165/165 [==============================] - 2s 11ms/step - loss: 2.9789 - val_loss: 3.8158
# Epoch 5/15
# 165/165 [==============================] - 2s 11ms/step - loss: 2.9320 - val_loss: 4.4085
# Epoch 6/15
# 165/165 [==============================] - 2s 11ms/step - loss: 2.9967 - val_loss: 3.3436
# Epoch 7/15
# 165/165 [==============================] - 2s 10ms/step - loss: 2.9777 - val_loss: 3.1539
# Epoch 8/15
# 165/165 [==============================] - 2s 15ms/step - loss: 2.9199 - val_loss: 3.4250
# Epoch 9/15
# 165/165 [==============================] - 2s 14ms/step - loss: 2.9242 - val_loss: 3.1198
# Epoch 10/15
# 165/165 [==============================] - 2s 11ms/step - loss: 2.9768 - val_loss: 3.2457
# Epoch 11/15
# 165/165 [==============================] - 2s 11ms/step - loss: 2.9525 - val_loss: 3.3377
# Epoch 12/15
# 165/165 [==============================] - 2s 11ms/step - loss: 2.8488 - val_loss: 3.3483
# Epoch 13/15
# 165/165 [==============================] - 2s 11ms/step - loss: 2.8412 - val_loss: 3.5439
# Epoch 14/15
# 165/165 [==============================] - 2s 11ms/step - loss: 2.8638 - val_loss: 3.8042
# Epoch 15/15
# 165/165 [==============================] - 2s 13ms/step - loss: 2.9731 - val_loss: 3.4227
# 183/183 [==============================] - 1s 3ms/step
#  the 650 samples have been concatenated
# Best Threshold= 4.955491
# fan_id_06 6 dB 62 completed

# %% [markdown]
# # CAE Model

# %%
ids =['fan_id_00','fan_id_02','fan_id_04','fan_id_06']
#Change the id to any of the following series
#['pump_id_00','pump_id_02','pump_id_04','pump_id_06']
#['fan_id_00','fan_id_02','fan_id_04','fan_id_06']#
random_states = [42, 52, 62]
snr = ['-6 dB', '0 dB', '6 dB']
# Create an empty DataFrame to store the results
for idx in ids:
    results_df = pd.DataFrame(columns=[
        "Machine Type",
        "Machine Number",
        "SNR",
        "Random State Run Number",
        "ROC-AUC",
        "Accuracy",
        "Precision",
        "Recall",
        "F1-Score"
    ])
    machine_type = 'Fan'#'Pump'
    id = idx

    for noise in snr:
        for j in random_states:
            random_state = j
            tf.random.set_seed= random_state
            np.random.seed = random_state

            file_path = fr"/content/drive/MyDrive/cnn preprocess/{id}/{noise}/{str(j)}/"
            X_train =np.load(fr"{file_path}X_train.npy")
            X_test =np.load(fr"{file_path}X_test.npy")
            ground_truth_file = np.load(fr"{file_path}ground_truth.npy")

            # Reshape the data to (650*9, 128, 32, 1) for training
            X_train_reshaped = X_train.reshape(-1, 128, 32, 1)
            X_test_reshaped = X_test.reshape(-1,128,32,1)


            #####################
            # Get the CAE model
            cae_model = get_model(inputDim = (128, 32), latentDim=32)  # You can customize the latent dimension
            early_stopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001)

            # Compile the model
            learning_rate = 0.001
            optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

            # Compile the model
            cae_model.compile(optimizer=optimizer, loss='mean_squared_error')  # Using MSE as the loss function

            # Train the model
            epochs = 25  # You can adjust the number of training epochs
            batch_size = 32  # You can adjust the batch size

            # Use the fit method to train the model
            history = cae_model.fit(X_train_reshaped,
                                    X_train_reshaped,
                                    epochs=epochs,
                                    verbose=0,
                                    batch_size=batch_size,
                                    validation_split=0.2,
                                    callbacks=[early_stopping])

            # Make predictions on the test data
            reconstructed_data = cae_model.predict(X_test_reshaped)
            # Calculate the reconstruction error for each sample
            mse = np.mean(np.square(X_test_reshaped - reconstructed_data), axis=1)
            ground_truth = list(ground_truth_file)

            # MSE of entire concatenated sample
            outcome_arr = []
            for i in range(len(mse)):
                if i % 9 == 0:
                    outcome_arr.append(np.average(mse[i:i+9]))
            print(f" the {len(outcome_arr)} samples have been concatenated")

            # ROC AUC SCORE
            fpr, tpr, thresholds = roc_curve(ground_truth, outcome_arr)
            roc_auc = auc(fpr, tpr)

            # get the best threshold using Youdens Index
            J = tpr - fpr
            ix = np.argmax(J)
            best_thresh = thresholds[ix]
            print('Best Threshold= %f' % (best_thresh))

            outcome = [0 if i < best_thresh else 1 for i in outcome_arr]

            y_pred = outcome

            accuracy = accuracy_score(ground_truth, y_pred)
            precision = precision_score(ground_truth, y_pred)
            recall = recall_score(ground_truth, y_pred)
            f1 = f1_score(ground_truth, y_pred)

            # Open the text file in append mode
                    # Append the results to the DataFrame
            results_df = results_df.append({
                "Machine Type": machine_type,
                "Machine Number": id,
                "SNR": noise,
                "Random State Run Number": random_state,
                "ROC-AUC": roc_auc,
                "Accuracy": accuracy,
                "Precision": precision,
                "Recall": recall,
                "F1-Score": f1
            }, ignore_index=True)

            #Loss Curve
            plt.figure()
            plt.plot(history.history['loss'], lw=2, color='darkblue')
            plt.plot(history.history['val_loss'], lw=2, color='darkorange')
            plt.title('Autoencoder Loss for CAE model')
            plt.xlabel('Epoch')
            plt.ylabel('Loss')
            plt.legend(['Train', 'Validation'], loc='upper right')
            file_path = f"/content/drive/MyDrive/CAE Results/Loss Curves/{id} {noise} {random_state} Loss Curve.png"
            plt.savefig(file_path)
            plt.close()


            #mse curve
            halfway_point = len(mse)/2  # enter halfway point
            plt.figure(figsize=(15, 5))
            # Plot the entire data
            # Create discrete x-values for the bar plot
            x_values = np.arange(len(outcome_arr))
            # Plot the entire data as discrete bars
            plt.scatter(x_values, outcome_arr, marker='o', label='MSE', s=5, color='black')
            # plt.plot(outcome_arr, )
            # Highlight the right half with a different background color
            plt.axhline(y=best_thresh, color='r', linestyle='-', label=f'threshold = {best_thresh:.4f}')
            plt.axvspan(halfway_point, len(outcome_arr), facecolor='green', alpha=0.2, label='Abnormal Test Data')
            plt.xlabel("Audio sample")
            plt.ylabel("MSE")
            plt.title("MSE of Test Data")
            plt.axvspan(0, halfway_point, facecolor='white', alpha=0.1, label='Normal Test Data')
            plt.legend()  # Add a legend to label the plot elements
            file_path = f"/content/drive/MyDrive/CAE Results/MSE Graphs/{id} {noise} {random_state} MSE Graph.png"
            plt.savefig(file_path)
            plt.close()

            #ROC Plot
            plt.figure()
            lw = 2
            plt.plot(fpr, tpr, color='darkorange',
                    lw=lw, label='ROC curve (area = %0.3f)' % roc_auc)
            plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
            plt.xlim([0.0, 1.0])
            plt.ylim([0.0, 1.05])
            plt.xlabel('False Positive Rate')
            plt.ylabel('True Positive Rate')
            plt.title('Receiver operating characteristic')
            plt.legend(loc="lower right")
            file_path = f"/content/drive/MyDrive/CAE Results/ROC Curves/{id} {noise} {random_state} ROC Curve.png"
            plt.savefig(file_path)
            plt.close()

            # confusion matrix
            conf_mat = confusion_matrix(ground_truth, outcome)
            plt.figure()
            sns.heatmap(conf_mat, cmap="Greens", annot=True, cbar_kws={"label": "Count"}, fmt='d',
                        xticklabels=[0, 1], yticklabels=[0, 1])
            plt.xlabel("Predicted Values")
            plt.ylabel("Actual Values")
            plt.title("Confusion Matrix")
            file_path = f"/content/drive/MyDrive/CAE Results/Confusion Matrices/{id} {noise} {random_state} confusion_matrix.png"
            plt.savefig(file_path)
            plt.close()

            model_path = f"/content/drive/MyDrive/CAE Results/Models/{id} {noise} {random_state} model"
            cae_model.save(model_path)

            print(f"{id} {noise} {random_state} completed")



    csv_file_path = f'/content/drive/MyDrive/CAE Results/Result Metrics/results_{id}_cnn.csv'
    #Save the DataFrame to a CSV file
    results_df.to_csv(csv_file_path, index=False)

#print(f"Results saved to {csv_file_path}")
# Out:
# 183/183 [==============================] - 2s 11ms/step
#  the 650 samples have been concatenated
# Best Threshold= 2.142015
# fan_id_00 -6 dB 42 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 3.700976
# fan_id_00 -6 dB 52 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 2.767649
# fan_id_00 -6 dB 62 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 1.900491
# fan_id_00 0 dB 42 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 2.793451
# fan_id_00 0 dB 52 completed
# 183/183 [==============================] - 2s 11ms/step
#  the 650 samples have been concatenated
# Best Threshold= 2.389297
# fan_id_00 0 dB 62 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 2.394622
# fan_id_00 6 dB 42 completed
# 183/183 [==============================] - 2s 12ms/step
#  the 650 samples have been concatenated
# Best Threshold= 4.814653
# fan_id_00 6 dB 52 completed
# 183/183 [==============================] - 2s 10ms/step
#  the 650 samples have been concatenated
# Best Threshold= 3.859504
# fan_id_00 6 dB 62 completed
# 183/183 [==============================] - 2s 10ms/step
#  the 650 samples have been concatenated
# Best Threshold= 1.415458
# fan_id_02 -6 dB 42 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 1.420355
# fan_id_02 -6 dB 52 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 1.759297
# fan_id_02 -6 dB 62 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 1.392935
# fan_id_02 0 dB 42 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 1.270462
# fan_id_02 0 dB 52 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 1.219980
# fan_id_02 0 dB 62 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 4.967053
# fan_id_02 6 dB 42 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 0.920383
# fan_id_02 6 dB 52 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 16.538607
# fan_id_02 6 dB 62 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 2.199728
# fan_id_04 -6 dB 42 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 2.374090
# fan_id_04 -6 dB 52 completed
# 183/183 [==============================] - 2s 10ms/step
#  the 650 samples have been concatenated
# Best Threshold= 2.493147
# fan_id_04 -6 dB 62 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 2.566184
# fan_id_04 0 dB 42 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 1.323841
# fan_id_04 0 dB 52 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 5.610985
# fan_id_04 0 dB 62 completed
# 183/183 [==============================] - 2s 10ms/step
#  the 650 samples have been concatenated
# Best Threshold= 0.999030
# fan_id_04 6 dB 42 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 14.180882
# fan_id_04 6 dB 52 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 2.313886
# fan_id_04 6 dB 62 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 1.798625
# fan_id_06 -6 dB 42 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 1.850248
# fan_id_06 -6 dB 52 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 2.380944
# fan_id_06 -6 dB 62 completed
# 183/183 [==============================] - 2s 10ms/step
#  the 650 samples have been concatenated
# Best Threshold= 1.726691
# fan_id_06 0 dB 42 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 1.852730
# fan_id_06 0 dB 52 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 1.821517
# fan_id_06 0 dB 62 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 2.743429
# fan_id_06 6 dB 42 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 2.276096
# fan_id_06 6 dB 52 completed
# 183/183 [==============================] - 2s 9ms/step
#  the 650 samples have been concatenated
# Best Threshold= 8.845660
# fan_id_06 6 dB 62 completed
